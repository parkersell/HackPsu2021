# %%
import browserhistory as bh
import pandas as pd

# %%
bh.write_browserhistory_csv()
# Out:
# * Notification *
# Please Completely Close CHROME Window

# %%
hi

# %%
dict_obj = bh.get_browserhistory()
# Out:
# * Notification *
# Please Completely Close CHROME Window

# %%
len(dict_obj)
# Out:
# 1

# %%
# Out:
# {'chrome': []}

# %%
hi = pd.read_csv("chrome_history.csv")

# %%
hi.iloc[:,1].tolist()
# Out:
# ['browser history python - Google Search',
#  'Analyse your web browsing history using Python - Open Source For You',
#  'Analyse your web browsing history using Python - Open Source For You',
#  'how to get browserhistory python scripte - Google Search',
#  'Get Browser History using Python in Ubuntu - GeeksforGeeks',
#  'why does browserhistory python say completely close window - Google Search',
#  'Python Module that Extracts the Browsers History : Python',
#  'Looking through JSOn - Jupyter Notebook',
#  'OneDrive - The Pennsylvania State University/Clubs/HackPSU/',
#  'OneDrive - The Pennsylvania State University/Clubs/',
#  'OneDrive - The Pennsylvania State University/',
#  'Home Page - Select or create a notebook',
#  'Home Page - Select or create a notebook',
#  'Opening Jupyter Notebook',
#  'Get Browser History(Chrome & Firefox) using Python in Ubuntu 16.04 | by Manivannan Murugavel | Medium',
# ...

# %%
hi1
# Out:
#        url  title  datetime
# 0      NaN    NaN       NaN
# 1      NaN    NaN       NaN
# 2      NaN    NaN       NaN
# 3      NaN    NaN       NaN
# 4      NaN    NaN       NaN
# ...    ...    ...       ...
# 10348  NaN    NaN       NaN
# 10349  NaN    NaN       NaN
# 10350  NaN    NaN       NaN
# 10351  NaN    NaN       NaN
# 10352  NaN    NaN       NaN
#
# [10353 rows x 3 columns]
